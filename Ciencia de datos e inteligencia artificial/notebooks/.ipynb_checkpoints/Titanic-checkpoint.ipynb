# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from os import path

# %%
train_path=path.join('res','titanic','train.csv')
test_path=path.join('res','titanic','test.csv')

# %% [markdown]
# ### Cargamos los datos de entrenamiento

# %%
train_data=pd.read_csv(train_path)
train_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# ## Cargamos los datos de test

# %%
test_data=pd.read_csv(test_path)
test_data.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_data.describe(include='all')
# Out:
#         PassengerId      Pclass              Name   Sex         Age  \
# count    418.000000  418.000000               418   418  332.000000
# unique          NaN         NaN               418     2         NaN
# top             NaN         NaN  Kelly, Mr. James  male         NaN
# freq            NaN         NaN                 1   266         NaN
# mean    1100.500000    2.265550               NaN   NaN   30.272590
# std      120.810458    0.841838               NaN   NaN   14.181209
# min      892.000000    1.000000               NaN   NaN    0.170000
# 25%      996.250000    1.000000               NaN   NaN   21.000000
# 50%     1100.500000    3.000000               NaN   NaN   27.000000
# 75%     1204.750000    3.000000               NaN   NaN   39.000000
# max     1309.000000    3.000000               NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# count   418.000000  418.000000       418  417.000000               91      418
# unique         NaN         NaN       363         NaN               76        3
# top            NaN         NaN  PC 17608         NaN  B57 B59 B63 B66        S
# freq           NaN         NaN         5         NaN                3      270
# mean      0.447368    0.392344       NaN   35.627188              NaN      NaN
# std       0.896760    0.981429       NaN   55.907576              NaN      NaN
# min       0.000000    0.000000       NaN    0.000000              NaN      NaN
# 25%       0.000000    0.000000       NaN    7.895800              NaN      NaN
# 50%       0.000000    0.000000       NaN   14.454200              NaN      NaN
# 75%       1.000000    0.000000       NaN   31.500000              NaN      NaN
# max       8.000000    9.000000       NaN  512.329200              NaN      NaN

# %%
sns.barplot(x='Embarked',y='Survived',hue='Sex',data=train_data)
# Out:
# <AxesSubplot: xlabel='Embarked', ylabel='Survived'>

# %%
sns.pointplot(x='Pclass',y='Survived',hue='Sex',data=train_data)
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Survived'>

# %%
edades=list(train_data.Age.unique())
edades.sort()
print(edades)
print(len(edades))
# Out:
# [0.83, 2.0, 3.0, 4.0, 5.0, 7.0, 8.0, 11.0, 14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0, 26.0, 27.0, 28.0, 28.5, 29.0, 30.0, 31.0, 32.0, 33.0, 34.0, 35.0, 38.0, nan, 0.42, 0.67, 0.75, 0.92, 1.0, 6.0, 9.0, 10.0, 12.0, 13.0, 14.5, 20.5, 23.5, 24.5, 30.5, 32.5, 34.5, 36.0, 36.5, 37.0, 39.0, 40.0, 40.5, 41.0, 42.0, 43.0, 44.0, 45.0, 45.5, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 52.0, 53.0, 54.0, 55.0, 55.5, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 70.0, 70.5, 71.0, 74.0, 80.0]
# 89

# %%
train_data.hist(column='Age')
plt.show()

# %%
def cat_age(data):
    ''' 
    A los que no tengan edades(NaN) se les asigna edad de -0.5
    Bines: -1,0,12,18,30,60,120
    input: pd Dataframe
    output: pd Dataframe
    '''
    data['Age']=data['Age'].fillna(-0.5)#rellenar los NaN
    bins=(-1,0,12,18,30,60,120)
    cat_names=['Unkown','Child','Teenagers','Young Adult','Adult','Elderly']
    categorias=pd.cut(data['Age'],bins,labels=cat_names)
    data['Age']=categorias
    return

# %%
cat_age(train_data)

# %%
cat_age(test_data)

# %%
train_data.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 861          862         0       2
# 736          737         0       3
# 238          239         0       2
# 189          190         0       3
# 160          161         0       3
# 806          807         0       1
# 793          794         0       1
# 348          349         1       3
# 572          573         1       1
# 473          474         1       2
#
#                                              Name     Sex          Age  SibSp  \
# 861                   Giles, Mr. Frederick Edward    male  Young Adult      1
# 736       Ford, Mrs. Edward (Margaret Ann Watson)  female        Adult      1
# 238               Pengelly, Mr. Frederick William    male  Young Adult      0
# 189                           Turcin, Mr. Stjepan    male        Adult      0
# 160                      Cribb, Mr. John Hatfield    male        Adult      0
# 806                        Andrews, Mr. Thomas Jr    male        Adult      0
# 793                      Hoyt, Mr. William Fisher    male       Unkown      0
# 348        Coutts, Master. William Loch "William"    male        Child      1
# 572              Flynn, Mr. John Irwin ("Irving")    male        Adult      0
# 473  Jerwan, Mrs. Amin S (Marie Marthe Thuillard)  female  Young Adult      0
#
#      Parch           Ticket     Fare Cabin Embarked
# 861      0            28134  11.5000   NaN        S
# 736      3       W./C. 6608  34.3750   NaN        S
# 238      0            28665  10.5000   NaN        S
# 189      0           349247   7.8958   NaN        S
# 160      1           371362  16.1000   NaN        S
# 806      0           112050   0.0000   A36        S
# 793      0         PC 17600  30.6958   NaN        C
# 348      1       C.A. 37671  15.9000   NaN        S
# 572      0         PC 17474  26.3875   E25        S
# 473      0  SC/AH Basle 541  13.7917     D        C

# %%
test_data.sample(5)
# Out:
#      PassengerId  Pclass                            Name     Sex          Age  \
# 120         1012       2            Watt, Miss. Bertha J  female        Child
# 154         1046       3    Asplund, Master. Filip Oscar    male    Teenagers
# 412         1304       3  Henriksson, Miss. Jenny Lovisa  female  Young Adult
# 237         1129       3             Baccos, Mr. Raffull    male  Young Adult
# 36           928       3             Roth, Miss. Sarah A  female       Unkown
#
#      SibSp  Parch      Ticket     Fare Cabin Embarked
# 120      0      0  C.A. 33595  15.7500   NaN        S
# 154      4      2      347077  31.3875   NaN        S
# 412      0      0      347086   7.7750   NaN        S
# 237      0      0        2679   7.2250   NaN        C
# 36       0      0      342712   8.0500   NaN        S

# %% [markdown]
# ## ¿Que hacemos con los camarotes?

# %%
sns.countplot(x='Cabin',data=train_data)
# Out:
# <AxesSubplot: xlabel='Cabin', ylabel='count'>

# %%
def extract_cabin(data):
    data['Cabin']=data['Cabin'].fillna('N')
    data['Cabin']=data['Cabin'].apply(lambda x: x[0])
    return

# %%
extract_cabin(train_data)

# %%
extract_cabin(test_data)

# %%
train_data.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 434          435         0       1              Silvey, Mr. William Baird
# 377          378         0       1              Widener, Mr. Harry Elkins
# 312          313         0       2  Lahtinen, Mrs. William (Anna Sylfven)
# 592          593         0       3             Elsbury, Mr. William James
# 19            20         1       3                Masselmani, Mrs. Fatima
#
#         Sex          Age  SibSp  Parch    Ticket     Fare Cabin Embarked cabin
# 434    male        Adult      1      0     13507   55.900     E        S   E44
# 377    male  Young Adult      0      2    113503  211.500     C        C   C82
# 312  female  Young Adult      1      1    250651   26.000     N        S     N
# 592    male        Adult      0      0  A/5 3902    7.250     N        S     N
# 19   female       Unkown      0      0      2649    7.225     N        C     N

# %%
test_data.sample(5)
# Out:
#      PassengerId  Pclass                               Name   Sex  \
# 143         1035       2         Beauchamp, Mr. Henry James  male
# 192         1084       3  van Billiard, Master. Walter John  male
# 101          993       2                 Weisz, Mr. Leopold  male
# 377         1269       2       Cotterill, Mr. Henry Harry""  male
# 259         1151       3           Midtsjo, Mr. Karl Albert  male
#
#              Age  SibSp  Parch    Ticket    Fare Cabin Embarked cabin
# 143  Young Adult      0      0    244358  26.000     N        S     N
# 192        Child      1      1  A/5. 851  14.500     N        S     N
# 101  Young Adult      1      0    228414  26.000     N        S     N
# 377  Young Adult      0      0     29107  11.500     N        S     N
# 259  Young Adult      0      0    345501   7.775     N        S     N

# %% [markdown]
# ## Precios

# %%
def cat_fare(data):
    data['Fare']=data['Fare'].fillna(0.0)
    cat_names=['1st','2nd','3rd','4th','5th']
    data['Fare']=pd.qcut(data['Fare'],5,labels=cat_names)
    return

# %%
cat_fare(train_data)
cat_fare(test_data)

# %%
train_data.sample(10)
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch Fare  \
# 235          236         0       3  female     Unkown      0      0  1st
# 179          180         0       3    male      Adult      0      0  1st
# 561          562         0       3    male      Adult      0      0  2nd
# 686          687         0       3    male  Teenagers      4      1  4th
# 284          285         0       1    male     Unkown      0      0  4th
# 749          750         0       3    male      Adult      0      0  1st
# 76            77         0       3    male     Unkown      0      0  2nd
# 405          406         0       2    male      Adult      1      0  3rd
# 381          382         1       3  female      Child      0      2  3rd
# 78            79         1       2    male      Child      0      2  4th
#
#     Cabin    Title
# 235     N    Miss.
# 179     N      Mr.
# 561     N      Mr.
# 686     N      Mr.
# 284     A      Mr.
# 749     N      Mr.
# 76      N      Mr.
# 405     N      Mr.
# 381     N    Miss.
# 78      N  Master.

# %%
test_data.sample(10)
# Out:
#      PassengerId  Pclass     Sex          Age  SibSp  Parch Fare Cabin  \
# 319         1211       2    male  Young Adult      2      0  4th     N
# 236         1128       1    male      Elderly      1      0  5th     D
# 258         1150       2  female  Young Adult      0      0  3rd     N
# 91           983       3    male       Unkown      0      0  1st     N
# 11           903       1    male        Adult      0      0  4th     N
# 382         1274       3  female       Unkown      0      0  3rd     N
# 318         1210       3    male  Young Adult      0      0  2nd     N
# 379         1271       3    male        Child      4      2  4th     N
# 213         1105       2  female        Adult      1      0  4th     N
# 3            895       3    male  Young Adult      0      0  2nd     N
#
#        Title
# 319      Mr.
# 236      Mr.
# 258    Miss.
# 91       Mr.
# 11       Mr.
# 382     Mrs.
# 318      Mr.
# 379  Master.
# 213     Mrs.
# 3        Mr.

# %% [markdown]
# ## Nombres

# %%
train_data['Name'].sample(15)
# Out:
# 886                          Montvila, Rev. Juozas
# 131                 Coelho, Mr. Domingos Fernandeo
# 424                    Rosblom, Mr. Viktor Richard
# 667                     Rommetvedt, Mr. Knud Paust
# 115                          Pekoniemi, Mr. Edvard
# 80                            Waelens, Mr. Achille
# 845                            Abbing, Mr. Anthony
# 838                                Chip, Mr. Chang
# 567    Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 271                   Tornquist, Mr. William Henry
# 818               Holm, Mr. John Fredrik Alexander
# 105                          Mionoff, Mr. Stoytcho
# 413                 Cunningham, Mr. Alfred Fleming
# 62                     Harris, Mr. Henry Birkhardt
# 371                      Wiklund, Mr. Jakob Alfred
# Name: Name, dtype: object

# %%
def extract_title(data):
    data['Title']=data['Name'].apply(lambda x: x.split()[1])

# %%
extract_title(train_data)
extract_title(test_data)

# %%
train_data.sample(10)
# Out:
#      PassengerId  Survived  Pclass     Sex          Age  SibSp  Parch Fare  \
# 382          383         0       3    male        Adult      0      0  2nd
# 508          509         0       3    male  Young Adult      0      0  4th
# 596          597         1       2  female       Unkown      0      0  4th
# 819          820         0       3    male        Child      3      2  4th
# 440          441         1       2  female        Adult      1      1  4th
# 379          380         0       3    male  Young Adult      0      0  1st
# 474          475         0       3  female  Young Adult      0      0  2nd
# 746          747         0       3    male    Teenagers      1      1  3rd
# 20            21         0       2    male        Adult      0      0  4th
# 857          858         1       1    male        Adult      0      0  4th
#
#     Cabin    Title
# 382     N      Mr.
# 508     N      Mr.
# 596     N    Miss.
# 819     N  Master.
# 440     N     Mrs.
# 379     N      Mr.
# 474     N    Miss.
# 746     N      Mr.
# 20      N      Mr.
# 857     E      Mr.

# %%
test_data.sample(10)
# Out:
#      PassengerId  Pclass     Sex          Age  SibSp  Parch Fare Cabin  \
# 115         1007       3    male    Teenagers      1      0  3rd     N
# 132         1024       3  female       Unkown      0      4  4th     N
# 379         1271       3    male        Child      4      2  4th     N
# 377         1269       2    male  Young Adult      0      0  3rd     N
# 41           933       1    male       Unkown      0      0  4th     D
# 134         1026       3    male        Adult      0      0  2nd     N
# 11           903       1    male        Adult      0      0  4th     N
# 160         1052       3  female       Unkown      0      0  1st     N
# 385         1277       2  female  Young Adult      1      2  5th     N
# 142         1034       1    male      Elderly      1      3  5th     B
#
#        Title
# 115      Mr.
# 132     Mrs.
# 379  Master.
# 377      Mr.
# 41       Mr.
# 134      Mr.
# 11       Mr.
# 160    Miss.
# 385    Miss.
# 142      Mr.

# %% [markdown]
# ## Eliminar

# %%
columns_to_drop=['cabin']
def drop_columns(data,columns):
    data.drop(columns,axis=1,inplace=True)

# %%
drop_columns(train_data,columns_to_drop)
drop_columns(test_data,columns_to_drop)

# %%
train_data.sample(5)
# Out:
#      PassengerId  Survived  Pclass     Sex          Age  SibSp  Parch  \
# 888          889         0       3  female       Unkown      1      2
# 719          720         0       3    male        Adult      0      0
# 26            27         0       3    male       Unkown      0      0
# 48            49         0       3    male       Unkown      2      0
# 565          566         0       3    male  Young Adult      2      0
#
#         Fare Cabin  Title
# 888  23.4500     N  Miss.
# 719   7.7750     N    Mr.
# 26    7.2250     N    Mr.
# 48   21.6792     N    Mr.
# 565  24.1500     N    Mr.

# %%
test_data.sample(5)
# Out:
#      PassengerId  Pclass     Sex          Age  SibSp  Parch     Fare Cabin  \
# 341         1233       3    male        Adult      0      0   7.5792     N
# 36           928       3  female       Unkown      0      0   8.0500     N
# 176         1068       2  female  Young Adult      0      0  36.7500     N
# 354         1246       3  female        Child      1      2  20.5750     N
# 225         1117       3  female       Unkown      0      2  15.2458     N
#
#      Title
# 341    Mr.
# 36   Miss.
# 176  Miss.
# 354  Miss.
# 225   Mrs.

# %%
sns.barplot(x='Age',y='Survived',hue='Sex',data=train_data)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Survived'>

# %%
sns.barplot(x='Fare', y='Survived',hue='Sex',data=train_data)
# Out:
# <AxesSubplot: xlabel='Fare', ylabel='Survived'>

# %% [markdown]
# ## Modelando

# %% [markdown]
# ## Codificar nuestras variables categóricas en forma de números

# %%
from sklearn import preprocessing

# %%
df_train=train_data.copy()

# %%
df_test=test_data.copy()

# %%
def encode_features(df_train,df_test,features):
    ''' '''
    df_combined=pd.concat([df_train[features],df_test[features]])
    
    for feature in features:
        le=preprocessing.LabelEncoder()
        le=le.fit(df_combined[feature])
        df_train[feature]=le.transform(df_train[feature])
        df_test[feature]=le.transform(df_test[feature])
        print(f'Feature {feature} OK')

# %%
features=['Sex','Age','Fare','Cabin','Title']
encode_features(df_train,df_test,features)
df_train.sample(5)
# Out:
# Feature Sex OK
# Feature Age OK
# Feature Fare OK
# Feature Cabin OK
# Feature Title OK
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Cabin  Title
# 493          494         0       1    1    2      0      0     4      7     19
# 582          583         0       2    1    0      0      0     3      7     19
# 159          160         0       3    1    4      8      2     4      7     13
# 701          702         1       1    1    0      0      0     3      4     19
# 569          570         1       3    1    0      0      0     0      7     19

# %% [markdown]
# ## Train split

# %%
from sklearn.model_selection import train_test_split

# %%
y=df_train['Survived']
X=df_train.drop(['Survived','PassengerId'],axis=1)
validation_split=0.15
seed=42
X_train,X_validation,y_train,y_validation=train_test_split(X,y,test_size=validation_split,random_state=seed)

# %% [markdown]
# ## Hacemos un modelo

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score

preds=model.predict(X_validation)

# %%
accuracy_score(preds,y_validation)
# Out:
# 0.8059701492537313

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_validation,preds))
# Out:
# [[67 11]
#  [15 41]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_validation,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84        78
#            1       0.79      0.73      0.76        56
#
#     accuracy                           0.81       134
#    macro avg       0.80      0.80      0.80       134
# weighted avg       0.81      0.81      0.80       134
